# %% [markdown]
# # A Recommendation System from Reddit
#
# In this report, I aim to build a recommendation system for Reddit users (refered to as Redditors) using only their Reddit username.
#
# # Motivation
#
# In the age of the internet consumers have an abundance of choice. From movies to songs to every concievable product, it seems like we have access to more choice than we can every hope to exercise. To make the traversal of this infromation more manageable, many companies build recommendation systems to help their users find more meaningful content or products, with great success. Platforms like Netflix and YouTube would simply not exist if they could not match users with personalized content given their vast content libraries.
#
# However, the value we gain from these recommendation engines come at a cost. These websites collect a tremendous amount of data from us. Google and Facebook particularly track our every movement, not just on the internet but, since the proliferation of smartphones, in the physical world as well. In addition, this is a huge barrier to entry for startups since the information that sites like Amazon and Facebook have about their customers allows them to provide better suggestions than new platforms.
#
# This is why I set out to see if I could build a recommendation system for users who I have not collected any prior information from. I plan to explore how we can leverage existing, public data about a user to suggest interesting items they may find interesting. I wish to deploy this into a site that encourages a community to share interests and ideas together rather than with a corporation that is trying to sell them something.
#
# # The Products
#
# First of all, I had to select which products I wanted to suggest. Netflix suggests movies, YouTube suggests videos and Spotify suggests songs, but Amazon suggests all of these things and a whole lot more. However, Amazon's product discovery algorithm is mainly built on items that someone has already purchased. As a result, a user only gets recommendations based on products they are familiar with. This is to Amazon's advantage, since these products likely have a very high conversion rate. However, it does not lend itself well to finding novel products that are based on our interests rather than our purchase history.
#
# # Reddit as a window to the soul
#
# Reddit is one of the most visited sites on the internet. It is a meta forum where users can post links to interesting items for every topic imaginable and discuss them with millions of other people. One of the strongest reasons why Reddit appeals to so many is because of its anonymity. It is one of the few forums where you can sign up without an email address, and is a far cry from something like Facebook where you have profile pictures and family information. Therefore, redditors can be open and expressive about their interests. Indeed, their personalities are associated with their Reddit usernames rather than their real names. This may lead to trolling but that is outside the scope of this exercise.
#
# The true value of Reddit for this tool is that redditors comment on different topics, and we can access these topics. This means that by accessing the topics where they comment (known as subreddits), we can see which topics they are interested in. A clear limitation of this is that certain redditors only browse subreddits without commenting on them (colloquially known as 'lurking'). There is no way to access this information. Indeed, I do not even think that reddit makes the subreddits that a user is subscribed to public. Therefore, we have to use the comments and get the subreddits from them.
#
# # Collaborative Filtering
#
# There are a variety of ways that recommender systems can work. In order to harness the power of the social fabric of Reddit, I will use 'Collaborative Filtering'. Collaborative Filtering is a way to utilize user inputs to suggest products to similar users. Usually, it is done in the manner that if User 1 likes X,Y and Z and User 2 likes X and Y, there is a high probability that User 2 likes Z. This is the way that Amazon does it. However, we do not have access to the users purchase history and, like mentioned above, we want to suggest novel products that are independent of our target user's purchase history. Therefore, we extend the same concept to subreddits rather than products. In our case, we postulate that if User X and User Y comment on similar topics, they have similar tastes and therefore we can recommend the products that User X likes to User Y.
#
# # Getting Data
#
# For Collaborative Filtering to work, however, we need a seed dataset of products to suggest to our users. This is where most platforms fail in their recommender systems. Without this critical mass of data, there would be nothing to suggest. However, upon research, I found a particular subreddit that provided me with a workaround; r/randomactsofamazon.
#
# R/RandomActsOfAmazon is an offshoot of an idea that the Reddit community has had for a long time, the act of randomly gifting something to another redditor. It originated with R/RandonActsOfPizza where, like the title would suggest, redditors would gift each other pizza delivered to their doorstep. R/RandomActsOfAmazon takes this concept further and allows redditors to post wishlists of things they want from Amazon. These redditors then hope that some stranger might like them and buy them a gift from their wishlist. This data is perfect for me as this contains the products that a particular redditor wants/thinks are cool.
#
# After contacting the moderators for r/randomactsofamazon, I was referred to http://n8fq.org/temp/links.sql This is an sql dump of the entire database of active users on r/randomactsofamazon. It is a public site that is used to power functionality for r/randomactsofamazon and I was given permission to use it. I was able to parse this sql dump into a database and convert it into a csv file in another script (see github repo). I will use this csv file for my recommendation engine. I will also encourage users to gift their 'Reddit Twin' (i.e. the redditor in my database who is thier closest match) something from their wishlist.  However, since I do not have informed consent for every reddit user in my database, I will not disclose the reddit id of their twin. Amazon holds the address of the wishlist owner secret to allow for safe, anonymous gifting.
#
# Now, lets get to the good stuff.

# %% [markdown]
# Lets import our dependecies. In this case, we need pandas to manipulate our data and PRAW, the Python Reddit API Wrapper.
# Find out more about PRAW at https://praw.readthedocs.io/en/latest/

# %%
import pandas as pd
import praw

# %% [markdown]
# We instantiate our Reddit instance. We have registered this script with Reddit and obtained a key (client secret). The account details are mine.

# %%
reddit = praw.Reddit(client_id = 'tOwGdbmWXETjEA',
                    client_secret = 'FPfgf52wvSG0TN-y_wlTRavGlpU',
                    username = 'amazonrecommender',
                    password = 'amazon',
                    user_agent='test')

# %%
getsubs('abhi91')
# Out:
# {'4chan',
#  'Barca',
#  'Cricket',
#  'CryptoCurrency',
#  'Entrepreneur',
#  'FIFA',
#  'FantasyPL',
#  'Games',
#  'Gunners',
#  'Jokes',
#  'LiverpoolFC',
#  'MCFC',
#  'Overwatch',
#  'PS4Deals',
#  'ProgrammerHumor',
#  'The_Donald',
#  'TrueReddit',
#  'UNBGBBIIVCHIDCTIICBG',
#  'asoiaf',
#  'churning',
#  'consulting',
#  'cringe',
#  'datascience',
#  'financialindependence',
#  'gameofthrones',
#  'hearthstone',
#  'iamverysmart',
#  'investing',
#  'learnmachinelearning',
#  'me_irl',
#  'movies',
#  'pic',
#  'poker',
#  'politics',
#  'reactiongifs',
#  'rickandmorty',
#  'soccer',
#  'videos',
#  'wallstreetbets',
#  'whowouldwin'}

# %% [markdown]
# Lets import the data. We will have 3 columns, the username a raw link and a processed link that I have cleaned up and added tracking information to. This will allow me to monitor the traffic being sent to Amazon when the site is published. We will use 'New Url' in this program.

# %%
df = pd.DataFrame.from_csv('newlist.csv')
df.head()
# Out:
#            User                                               Link  \
# 0      Ali-Sama                    http://amzn.com/w/2ZCUBM2WM9JZQ
# 1        Rysona                    http://amzn.com/w/2AOCVWCB8FPZF
# 2        G0ATLY  http://smile.amazon.com/registry/wishlist/3RB6...
# 3  dancemasterv                                http://a.co/5xAfzvI
# 4    chunkopunk                    http://amzn.com/w/1Z4QEA0MGEXBU
#
#                                              New Url
# 0  https://www.amazon.com/gp/registry/wishlist/2Z...
# 1  https://www.amazon.com/gp/registry/wishlist/2A...
# 2  http://smile.amazon.com/registry/wishlist/3RB6...
# 3  https://www.amazon.com/registry/wishlist/2JKVV...
# 4  https://www.amazon.com/gp/registry/wishlist/1Z...

# %% [markdown]
# We now write a function that allows us to utilize PRAW to get the subreddits that a redditor has commented in. To keep in touch with the redditors current interests, we will only identify the most recent 500 comments. Note that we are using a set so that we have unique subreddits and these are not in any order. Also we need to normalize these by removing the most popular subreddits as well as randomactsofamazon. This will ensure that the subreddits that influence unique tastes are given higher weight.

# %%
defaultsubs = set(['announcements','funny','AskReddit','todayilearned','science','pics','IAmA','randomactsofamazon'])
def normalizesubs(usersubs):
    normalizedsubs = usersubs - defaultsubs
    return (normalizedsubs)
def getsubs(username):
    subs = set()
    redditor = reddit.redditor(str(username))
    for comment in redditor.comments.new(limit=500):
                    subs.add(str(comment.subreddit))                        
    #normalize subs by removing most popular subs.
    subs=normalizesubs(subs)
    return(subs)

# %% [markdown]
# In order to give our user a good experience, we need to minimize loading times for our recommendations. The most time consuming part of this whole script is extracting all the comments from a user. We can minimize this time by pulling a list of subreddits that our database of redditors have commented in as of today (12/10/2017). While this will mean that our recommendation engine is not dynamic with the changing interests of our database redditors, it significantly cuts down on loading time. We can update this list of subreddits at regular intervals in the future. We will append this list of subreddits to our dataframe.

# %%
#takes a long time. Just import redditproducts.csv and the code in that cell
subslist = []
for index,rows in df.iterrows():
    user = rows['User']
    print('Trying for user number: ',index,' username: ',user)
    try:
        subslist.append(getsubs(user))
    except :
        #if there is an error, the user has deleted their reddit account. Store Null and continue with the loop
        subslist.append('Null')
        print('user not there')
        continue
df['Subs']=subslist
# Out:
# Trying for user number:  0  username:  Ali-Sama
# Trying for user number:  1  username:  Rysona
# Trying for user number:  2  username:  G0ATLY
# Trying for user number:  3  username:  dancemasterv
# Trying for user number:  4  username:  chunkopunk
# Trying for user number:  5  username:  Browntizzle
# Trying for user number:  6  username:  rockinDS24
# Trying for user number:  7  username:  rsgamg
# Trying for user number:  8  username:  82364
# Trying for user number:  9  username:  RyanOver9000
# Trying for user number:  10  username:  L_Cranston_Shadow
# Trying for user number:  11  username:  neuromorph
# Trying for user number:  12  username:  havechanged
# Trying for user number:  13  username:  TAPorter
# Trying for user number:  14  username:  cj151695
# Trying for user number:  15  username:  NibbleFish
# Trying for user number:  16  username:  ninja_nicci
# Trying for user number:  17  username:  ShiroiMana
# Trying for user number:  18  username:  mitsimac
# Trying for user number:  19  username:  FirstLadyOfBeer
# Trying for user number:  20  username:  imscreamingrightnow
# Trying for user number:  21  username:  whiteandyellow
# Trying for user number:  22  username:  Balaguru_BR5
# Trying for user number:  23  username:  kanooka
# Trying for user number:  24  username:  ScarlettMaeBottom
# Trying for user number:  25  username:  Jacewoop23
# Trying for user number:  26  username:  t-minus5tosexy
# Trying for user number:  27  username:  MagicMistoffelees
# Trying for user number:  28  username:  Allybama
# Trying for user number:  29  username:  PapaRomeoAlpha
# Trying for user number:  30  username:  spilledbeans
# Trying for user number:  31  username:  nddragoon
# Trying for user number:  32  username:  ProbableErorr
# Trying for user number:  33  username:  lcarosella
# Trying for user number:  34  username:  theregoesmyeye
# user not there
# Trying for user number:  35  username:  discojaxx
# Trying for user number:  36  username:  Rayn_the_hunter
# Trying for user number:  37  username:  Envy_The_Jealous
# Trying for user number:  38  username:  TrocheeCity
# Trying for user number:  39  username:  Bucket4Life
# Trying for user number:  40  username:  ruphuselderbeer
# Trying for user number:  41  username:  Enovara
# Trying for user number:  42  username:  SEQU0IA
# Trying for user number:  43  username:  LittleMizPixie
# Trying for user number:  44  username:  spacesleep
# Trying for user number:  45  username:  EriSeguchi
# Trying for user number:  46  username:  kurosaba
# Trying for user number:  47  username:  Sp3cia1K
# Trying for user number:  48  username:  MMAPhreak21
# Trying for user number:  49  username:  SailoLee
# Trying for user number:  50  username:  Sieberella
# Trying for user number:  51  username:  GrtNPwrfulOz
# Trying for user number:  52  username:  kirklazaurs87
# Trying for user number:  53  username:  rarelyserious
# Trying for user number:  54  username:  giggidywarlock
# user not there
# Trying for user number:  56  username:  TwistedEnigma
# Trying for user number:  57  username:  watsoned
# Trying for user number:  58  username:  SukiTheGoat
# Trying for user number:  59  username:  MCubb
# Trying for user number:  60  username:  neongreenpurple
# Trying for user number:  61  username:  mewfasa
# Trying for user number:  62  username:  mattidallama
# Trying for user number:  63  username:  burke_no_sleeps
# Trying for user number:  64  username:  Headcall
# Trying for user number:  65  username:  paradoxikal
# Trying for user number:  66  username:  MKandtheforce
# Trying for user number:  67  username:  SirRipo
# Trying for user number:  68  username:  Rubenick
# Trying for user number:  69  username:  wee-pixie
# user not there
# Trying for user number:  70  username:  saratonin84
# Trying for user number:  71  username:  EdenSB
# Trying for user number:  72  username:  Girfex
# Trying for user number:  73  username:  windurr
# Trying for user number:  74  username:  s2xtreme4u
# Trying for user number:  75  username:  dragonflyjen
# Trying for user number:  76  username:  HeadlessBob17
# Trying for user number:  77  username:  krispykremedonuts
# Trying for user number:  78  username:  legotech
# Trying for user number:  79  username:  Akeleie
# Trying for user number:  80  username:  glanmiregirl
# Trying for user number:  81  username:  BuffHagen
# user not there
# Trying for user number:  82  username:  thatbossguy
# Trying for user number:  83  username:  Matronix
# Trying for user number:  84  username:  GhostOfTheNet
# Trying for user number:  85  username:  Brenhines
# Trying for user number:  86  username:  teatimeoclock
# Trying for user number:  87  username:  kayleighh
# Trying for user number:  88  username:  xX_Justin_Xx
# Trying for user number:  89  username:  Ajs1004
# Trying for user number:  90  username:  RCJhawk
# Trying for user number:  91  username:  ItsACharlieDay
# Trying for user number:  92  username:  OfMonstersAndSuicide
# Trying for user number:  93  username:  angelninja
# Trying for user number:  94  username:  Roehok
# Trying for user number:  95  username:  cupcakegiraffe
# Trying for user number:  96  username:  Kibure
# Trying for user number:  97  username:  LeftMySoulAtHome
# Trying for user number:  98  username:  paintnwood
# Trying for user number:  99  username:  lobstahfi
# Trying for user number:  100  username:  origami_rock
# Trying for user number:  101  username:  natalietoday
# Trying for user number:  102  username:  OverlyApologeticGuy
# Trying for user number:  103  username:  Chaela
# Trying for user number:  104  username:  bethydolla
# Trying for user number:  105  username:  Ereshkigal234
# Trying for user number:  106  username:  drzedwordhunter
# Trying for user number:  107  username:  hannaHananaB
# Trying for user number:  108  username:  ebooksgirl
# Trying for user number:  109  username:  0hfuck
# Trying for user number:  111  username:  homeallday
# Trying for user number:  112  username:  3dmesh
# Trying for user number:  113  username:  theCaitiff
# Trying for user number:  114  username:  Coffin_Nail
# Trying for user number:  115  username:  SphynxKitty
# Trying for user number:  116  username:  sylvar
# Trying for user number:  117  username:  Candroth
# Trying for user number:  118  username:  OptomisticOcelot
# Trying for user number:  119  username:  cthylla
# Trying for user number:  120  username:  effeduphealer
# Trying for user number:  121  username:  Liies
# Trying for user number:  122  username:  ichosethis
# Trying for user number:  123  username:  EmergencyPizza
# Trying for user number:  124  username:  aimeenew
# Trying for user number:  125  username:  stutterbutt
# Trying for user number:  126  username:  ApeOver
# Trying for user number:  127  username:  timelady84
# Trying for user number:  128  username:  trisarahdactyl
# Trying for user number:  129  username:  KittenAnne
# Trying for user number:  130  username:  Nemesis0320
# Trying for user number:  131  username:  travelersoul
# Trying for user number:  132  username:  draconorge
# Trying for user number:  133  username:  MsRocky
# Trying for user number:  134  username:  DiscoKittie
# Trying for user number:  135  username:  angel92591
# Trying for user number:  136  username:  R3bel_R3bel
# Trying for user number:  137  username:  Dee_Doubleyew_TTT
# Trying for user number:  138  username:  Junigole
# Trying for user number:  139  username:  hellooolady
# Trying for user number:  140  username:  titchard
# Trying for user number:  141  username:  Shercock_Holmes
# Trying for user number:  142  username:  book_worm526
# Trying for user number:  143  username:  themusicliveson
# Trying for user number:  144  username:  writerlib
# Trying for user number:  145  username:  Janiichan
# Trying for user number:  146  username:  UnBornPorn
# Trying for user number:  147  username:  nijoli
# Trying for user number:  148  username:  DoodlesAndSuch
# Trying for user number:  149  username:  imsamsam
# Trying for user number:  150  username:  Sneekyninja
# Trying for user number:  151  username:  browneyedgirl79
# Trying for user number:  152  username:  MoonPrisimPower
# Trying for user number:  153  username:  DrUsual
# Trying for user number:  154  username:  ink1026
# Trying for user number:  155  username:  dapamico
# Trying for user number:  156  username:  melumebelle
# Trying for user number:  157  username:  earthsick
# Trying for user number:  158  username:  MisterJimJim
# Trying for user number:  159  username:  dnd1980
# Trying for user number:  160  username:  TheRubyRedPirate
# Trying for user number:  161  username:  SardonicKiller
# Trying for user number:  162  username:  kramdiw
# Trying for user number:  163  username:  wirette
# Trying for user number:  164  username:  ThatGilbertKid
# Trying for user number:  165  username:  zzddjj
# Trying for user number:  166  username:  cinnabubbles
# Trying for user number:  167  username:  digitalyss
# user not there
# Trying for user number:  168  username:  charlimonster
# Trying for user number:  169  username:  RumpleAndBelle
# Trying for user number:  170  username:  Aerys1
# Trying for user number:  171  username:  SinnerOfAttention
# Trying for user number:  172  username:  doublestop23
# Trying for user number:  173  username:  LizziPizzo
# Trying for user number:  174  username:  Thesmy
# Trying for user number:  175  username:  Gedrean
# Trying for user number:  176  username:  Fr_Time
# Trying for user number:  177  username:  kleinePfoten
# Trying for user number:  178  username:  lilsting10
# Trying for user number:  179  username:  polkadotsunday
# Trying for user number:  180  username:  morelove
# Trying for user number:  181  username:  ununpentium89
# Trying for user number:  182  username:  GarbaGarba
# Trying for user number:  183  username:  poweredbyanxiety
# Trying for user number:  184  username:  browniebiznatch
# Trying for user number:  185  username:  ArtsyKitty
# Trying for user number:  186  username:  smeuchel
# Trying for user number:  187  username:  ajschuit
# Trying for user number:  188  username:  thegivinggirl
# Trying for user number:  189  username:  shazie13
# Trying for user number:  190  username:  PrincessMau
# Trying for user number:  191  username:  huto
# Trying for user number:  192  username:  SparklyDarkUnicorn
# Trying for user number:  193  username:  CelticMara
# Trying for user number:  194  username:  AlySedai
# Trying for user number:  195  username:  greenrob
# Trying for user number:  196  username:  chynncarmen
# Trying for user number:  197  username:  Blaidd_Drwg87
# Trying for user number:  198  username:  lonewolf13313
# Trying for user number:  199  username:  Zygsy
# Trying for user number:  200  username:  DarkOctober
# Trying for user number:  201  username:  SteampunkButterfly
# Trying for user number:  202  username:  ModernPrometheus0729
# Trying for user number:  203  username:  GenieHakeem
# Trying for user number:  204  username:  vinuash
# Trying for user number:  205  username:  ocelot777
# Trying for user number:  206  username:  shadowdra126
# Trying for user number:  207  username:  UEH
# Trying for user number:  208  username:  Smile_for_the_Camera
# Trying for user number:  209  username:  lemonylimey
# Trying for user number:  210  username:  thomaspayne25
# Trying for user number:  211  username:  Challis2070
# Trying for user number:  212  username:  KristinOhh
# Trying for user number:  213  username:  rockyhorrorgerri
# Trying for user number:  214  username:  pancakeman157
# Trying for user number:  215  username:  ScoliOsys
# Trying for user number:  216  username:  AuntChiladas
# Trying for user number:  217  username:  KunSeii
# Trying for user number:  218  username:  Adeno
# Trying for user number:  219  username:  Kelandry
# Trying for user number:  220  username:  EmmaBourbon
# Trying for user number:  221  username:  carissalf
# Trying for user number:  222  username:  BarelyOriginal
# Trying for user number:  223  username:  swirly023
# Trying for user number:  224  username:  linktm
# Trying for user number:  225  username:  Melium
# Trying for user number:  226  username:  happiness0101
# Trying for user number:  227  username:  mynthe
# Trying for user number:  228  username:  freedlvry
# Trying for user number:  229  username:  colette0101
# Trying for user number:  230  username:  scethao
# Trying for user number:  231  username:  Jakisparrow
# Trying for user number:  232  username:  shaynoodle
# Trying for user number:  233  username:  drkatherine1
# Trying for user number:  234  username:  naunum
# Trying for user number:  235  username:  chargingfungus
# Trying for user number:  236  username:  HondaGirlMN
# Trying for user number:  237  username:  SirNyan
# Trying for user number:  238  username:  MacabreChaos
# Trying for user number:  239  username:  kaijujube
# Trying for user number:  240  username:  CaptainCoral
# Trying for user number:  241  username:  WeAreLegionWeAreMany
# Trying for user number:  242  username:  idris_in_a_box
# Trying for user number:  243  username:  whocaresyo
# Trying for user number:  244  username:  SgtCheesepuffs
# Trying for user number:  245  username:  HamsterFarm
# user not there
# Trying for user number:  246  username:  briv
# Trying for user number:  247  username:  madsbrain
# user not there
# Trying for user number:  248  username:  NiceGirlSyndrome
# Trying for user number:  249  username:  xandirs
# Trying for user number:  250  username:  imisscrazylenny
# Trying for user number:  251  username:  SamuraiDDD
# Trying for user number:  252  username:  chiodos
# Trying for user number:  253  username:  SilverCosmos
# Trying for user number:  254  username:  catinadress
# Trying for user number:  255  username:  supertweak54
# Trying for user number:  256  username:  NeurotoxicNihilist
# Trying for user number:  257  username:  MuscleMansMum
# Trying for user number:  258  username:  redwinedrunk
# Trying for user number:  259  username:  BrandonCarlson
# Trying for user number:  260  username:  Cellophane_Girl
# Trying for user number:  261  username:  robertsinpants2
# Trying for user number:  262  username:  pancakesandhyrup
# Trying for user number:  263  username:  ptrix
# Trying for user number:  264  username:  ThorButhocks
# Trying for user number:  265  username:  perilouspixie
# Trying for user number:  266  username:  gracefulwing
# Trying for user number:  267  username:  relkosh
# Trying for user number:  268  username:  imaplatypuswithwings
# Trying for user number:  269  username:  Raewynrh
# Trying for user number:  270  username:  bderenzi
# Trying for user number:  271  username:  obeythegiant
# Trying for user number:  272  username:  RoseHearth
# Trying for user number:  273  username:  NotDescriptive
# Trying for user number:  274  username:  jskoker
# Trying for user number:  275  username:  kris10leigh
# Trying for user number:  276  username:  martinibini
# Trying for user number:  277  username:  iTiffany
# Trying for user number:  278  username:  xaitox
# Trying for user number:  279  username:  dichra
# Trying for user number:  280  username:  AKFlyingFish
# Trying for user number:  281  username:  ChimpTang
# Trying for user number:  282  username:  ottiecat
# user not there
# Trying for user number:  283  username:  nomscookies
# Trying for user number:  284  username:  FlailStorm
# Trying for user number:  285  username:  bicyclegeek
# Trying for user number:  286  username:  darth_advocate
# Trying for user number:  287  username:  OMFGJimbo
# Trying for user number:  288  username:  Take42
# Trying for user number:  289  username:  fembecca
# Trying for user number:  290  username:  cwf82
# Trying for user number:  291  username:  not-gonna-tell
# Trying for user number:  292  username:  AReluctantRedditor
# Trying for user number:  293  username:  bludart
# Trying for user number:  294  username:  ladyboss_1
# Trying for user number:  295  username:  neverlandishome
# Trying for user number:  296  username:  suzerz
# Trying for user number:  297  username:  Doctor-Kitten
# Trying for user number:  298  username:  Iphotoshopincats
# Trying for user number:  299  username:  dustinquickfire
# Trying for user number:  300  username:  Logic_85
# Trying for user number:  301  username:  mmb1117
# Trying for user number:  302  username:  cj1990
# Trying for user number:  303  username:  kittyportals2
# Trying for user number:  304  username:  OOmama
# Trying for user number:  305  username:  iammooseAMA
# Trying for user number:  306  username:  Doc_LaVoy
# Trying for user number:  307  username:  InkedLeo
# Trying for user number:  308  username:  angeltre
# Trying for user number:  309  username:  Punkcherri
# Trying for user number:  310  username:  Hollowlife6
# Trying for user number:  311  username:  teddydragonbear
# Trying for user number:  312  username:  quitelike
# Trying for user number:  313  username:  gotafewqs
# Trying for user number:  314  username:  jenni5
# Trying for user number:  315  username:  SatansUterus
# Trying for user number:  316  username:  MrZissman
# Trying for user number:  317  username:  swallowtails
# Trying for user number:  318  username:  GreatCatch
# Trying for user number:  319  username:  sarskatt
# Trying for user number:  320  username:  FaeryLynne
# Trying for user number:  321  username:  Kneecoleelaine
# Trying for user number:  322  username:  whynot1991
# Trying for user number:  323  username:  pinkfluffs
# Trying for user number:  324  username:  Fnerb
# Trying for user number:  325  username:  runslow
# Trying for user number:  326  username:  LadyDarkKitten
# Trying for user number:  327  username:  rubydoobiedooooo
# Trying for user number:  328  username:  LadyOops
# Trying for user number:  329  username:  codismycopilot
# Trying for user number:  330  username:  EskimoPrincess
# Trying for user number:  331  username:  crinnie
# Trying for user number:  332  username:  Catainia
# Trying for user number:  333  username:  Veronidge
# Trying for user number:  334  username:  Occulus2057
# Trying for user number:  335  username:  Aeoles
# Trying for user number:  336  username:  budgiebum
# Trying for user number:  337  username:  Usernameisntthatlong
# Trying for user number:  338  username:  ImpossibleKintsugi
# Trying for user number:  339  username:  Chexytime
# Trying for user number:  340  username:  Benisar
# Trying for user number:  341  username:  Derparita
# Trying for user number:  342  username:  hihelloneighboroonie
# Trying for user number:  343  username:  Jedi_Tinmf
# Trying for user number:  344  username:  Paralily
# Trying for user number:  345  username:  TheBestThatNeverWas
# Trying for user number:  346  username:  kurokitsune91
# Trying for user number:  347  username:  RavensAlehouse
# Trying for user number:  348  username:  Meat_tricycle
# Trying for user number:  349  username:  NinjaRabbitHamilton
# Trying for user number:  350  username:  SafariZoned_
# Trying for user number:  351  username:  shiky556
# Trying for user number:  352  username:  ZombieKilgore
# Trying for user number:  353  username:  KratzALot
# Trying for user number:  354  username:  BomNomNom
# Trying for user number:  355  username:  littlebean5ft
# Trying for user number:  356  username:  tanyeehou87
# Trying for user number:  357  username:  areraswen
# Trying for user number:  358  username:  capslion
# Trying for user number:  359  username:  geological-tech
# Trying for user number:  360  username:  ohhemma
# Trying for user number:  361  username:  mindscribes
# Trying for user number:  362  username:  SirSteve_
# Trying for user number:  363  username:  susieeQT
# Trying for user number:  364  username:  S103793
# Trying for user number:  365  username:  beclyn
# Trying for user number:  366  username:  jprata
# Trying for user number:  367  username:  loukin
# Trying for user number:  368  username:  paross
# Trying for user number:  369  username:  Lyd_Euh
# Trying for user number:  370  username:  EscapeArtistic
# Trying for user number:  371  username:  freakishkittie
# Trying for user number:  372  username:  skalafurey
# Trying for user number:  373  username:  mdhh99
# Trying for user number:  374  username:  bogmansaha
# Trying for user number:  375  username:  MangaMaven
# Trying for user number:  376  username:  ElfinPrincessMarlene
# Trying for user number:  377  username:  Pi_Maker
# Trying for user number:  378  username:  Nataliex90
# Trying for user number:  379  username:  stopeatingthechalk
# Trying for user number:  380  username:  huskeyeskimo
# Trying for user number:  381  username:  hidden_intuition
# Trying for user number:  382  username:  Poet1959
# Trying for user number:  383  username:  jassykangaroo
# Trying for user number:  384  username:  SailorPixie
# Trying for user number:  385  username:  rwturner
# Trying for user number:  386  username:  scarwiz
# Trying for user number:  387  username:  IamanIT
# Trying for user number:  388  username:  Belskirnir_
# Trying for user number:  389  username:  reinvented
# Trying for user number:  390  username:  concurthecity
# Trying for user number:  391  username:  Ryegan
# Trying for user number:  392  username:  Aisakura7
# Trying for user number:  393  username:  WeathersRabbits
# Trying for user number:  394  username:  8bitmadness
# Trying for user number:  395  username:  rosebert
# Trying for user number:  396  username:  AlbusGrumbledore
# Trying for user number:  397  username:  Jaz_Allen
# Trying for user number:  398  username:  nanabeams
# Trying for user number:  399  username:  brezofleur
# Trying for user number:  400  username:  Lady815
# Trying for user number:  401  username:  Gogohax
# Trying for user number:  402  username:  in_omniaparatus
# Trying for user number:  403  username:  declared_somnium
# Trying for user number:  404  username:  krisymkk
# Trying for user number:  405  username:  jfavre
# user not there
# Trying for user number:  406  username:  idunnoshutup
# Trying for user number:  407  username:  originofbeauty
# Trying for user number:  408  username:  LemonMeringueOctopi
# Trying for user number:  409  username:  trashboy
# Trying for user number:  410  username:  shadowbox86
# Trying for user number:  411  username:  7heDaniel
# Trying for user number:  412  username:  beddersox
# Trying for user number:  413  username:  melini
# Trying for user number:  414  username:  blazon_paradox
# Trying for user number:  415  username:  askignquestions
# Trying for user number:  416  username:  sami93
# Trying for user number:  417  username:  JLG22
# Trying for user number:  419  username:  chef_weenie
# Trying for user number:  420  username:  klinch3R
# Trying for user number:  421  username:  thehostilehobo
# Trying for user number:  422  username:  Idontknowflycasual
# Trying for user number:  423  username:  seriouslyjessie
# Trying for user number:  424  username:  PigeonFace
# Trying for user number:  425  username:  CylentShadow
# Trying for user number:  426  username:  laterdayze
# Trying for user number:  427  username:  DivineDimSum
# Trying for user number:  428  username:  toxic_kitten
# Trying for user number:  429  username:  Gainesy88
# Trying for user number:  430  username:  PatrickJamesYu
# Trying for user number:  431  username:  Renaki0586
# Trying for user number:  432  username:  c0delikeagirl
# Trying for user number:  433  username:  GoldenTimeHero
# Trying for user number:  434  username:  AffenMitWaffen
# Trying for user number:  435  username:  sammy0415
# Trying for user number:  436  username:  Gwyn07
# Trying for user number:  437  username:  HalNicci
# Trying for user number:  438  username:  uhlex28
# Trying for user number:  439  username:  Christypaints
# Trying for user number:  440  username:  Thatfoxylady
# Trying for user number:  441  username:  doctor_robocop
# Trying for user number:  442  username:  amber8705b
# Trying for user number:  443  username:  tydestra
# Trying for user number:  444  username:  Melvarkie
# Trying for user number:  445  username:  Celt42
# Trying for user number:  446  username:  happybabo
# Trying for user number:  447  username:  hippo-party
# Trying for user number:  448  username:  RESPEKTOR
# Trying for user number:  449  username:  challistwin
# Trying for user number:  450  username:  nessi_saltares
# Trying for user number:  451  username:  Princess_Panic
# Trying for user number:  452  username:  cutekick
# Trying for user number:  453  username:  Bubbles_the_Titan
# Trying for user number:  454  username:  TalisNightshade
# Trying for user number:  455  username:  iWishToBeAdoctor
# Trying for user number:  456  username:  girlfran69
# Trying for user number:  457  username:  damenleeturks
# Trying for user number:  458  username:  jessaloo
# Trying for user number:  459  username:  TurnOfFraise
# Trying for user number:  460  username:  Torisuta
# Trying for user number:  461  username:  amoz2k12
# Trying for user number:  462  username:  Yakko27
# Trying for user number:  463  username:  Mukaksi
# Trying for user number:  464  username:  CollatrlDamage
# user not there
# Trying for user number:  465  username:  Frogblaster77
# Trying for user number:  466  username:  AlphaHooker
# Trying for user number:  467  username:  CCV21
# Trying for user number:  468  username:  huge_ox
# Trying for user number:  469  username:  Synikull
# Trying for user number:  470  username:  AnguisetteAntha
# Trying for user number:  471  username:  mskalak
# Trying for user number:  472  username:  annaleiia
# Trying for user number:  473  username:  Legion991
# Trying for user number:  474  username:  lollialice
# Trying for user number:  475  username:  Beelazyy
# Trying for user number:  476  username:  duckingcluttered
# Trying for user number:  477  username:  katier127
# Trying for user number:  478  username:  Jonesxj
# Trying for user number:  479  username:  bettyellen
# Trying for user number:  480  username:  The_Ky_Guy
# Trying for user number:  481  username:  slaytebastardes
# user not there
# Trying for user number:  482  username:  UnicornBomber
# Trying for user number:  483  username:  maybeawolf
# Trying for user number:  484  username:  DrayKitty1331
# Trying for user number:  485  username:  acwellen
# Trying for user number:  486  username:  Iappreciatecats
# Trying for user number:  487  username:  clorissareed
# Trying for user number:  488  username:  Morthy
# Trying for user number:  489  username:  CatfishJunkie
# Trying for user number:  490  username:  Floppycakes
# Trying for user number:  491  username:  SinisterPyromaniac
# Trying for user number:  492  username:  Ty0005
# Trying for user number:  493  username:  therealsix
# Trying for user number:  494  username:  PoopOnMyBum
# Trying for user number:  495  username:  zombiexmuffinx
# Trying for user number:  496  username:  TyrawrD
# Trying for user number:  497  username:  CanadianHo
# user not there
# Trying for user number:  498  username:  bntyhntrqueen
# Trying for user number:  499  username:  yegwebdev
# Trying for user number:  500  username:  RobJob130
# Trying for user number:  501  username:  pinkbabyspice
# Trying for user number:  502  username:  Echo94
# Trying for user number:  503  username:  liebehass
# Trying for user number:  504  username:  argirl09
# Trying for user number:  505  username:  hatedheadspace
# Trying for user number:  506  username:  MistakenLoner
# Trying for user number:  507  username:  Spear585
# Trying for user number:  508  username:  Awkward-Octopus
# Trying for user number:  509  username:  Rhomra
# Trying for user number:  510  username:  nostableisotopes
# Trying for user number:  511  username:  Winter-Stardust
# Trying for user number:  512  username:  WhiteLaceTank
# Trying for user number:  513  username:  scupy42
# Trying for user number:  514  username:  Roxchic
# Trying for user number:  515  username:  punchyourbuns
# Trying for user number:  516  username:  rougerogue-
# Trying for user number:  517  username:  ShisaDog
# Trying for user number:  518  username:  plebian-seppuku
# Trying for user number:  519  username:  chobette
# Trying for user number:  520  username:  dogfacedpajamas
# Trying for user number:  521  username:  pigeonchase
# Trying for user number:  522  username:  illestprodigy
# Trying for user number:  523  username:  Shell058
# Trying for user number:  524  username:  S16_Drummer
# Trying for user number:  525  username:  NXVX
# Trying for user number:  526  username:  Dark_Saint
# Trying for user number:  527  username:  Jaymakk13
# Trying for user number:  528  username:  MadcapGhost
# Trying for user number:  529  username:  skelezombie
# Trying for user number:  530  username:  Sushiki
# Trying for user number:  531  username:  GiddyGiraffes
# Trying for user number:  532  username:  frytanya
# Trying for user number:  533  username:  Vap-n-ape
# Trying for user number:  534  username:  Perizade
# Trying for user number:  535  username:  hannfrank
# Trying for user number:  536  username:  shadowshea
# Trying for user number:  537  username:  pr_kitkat
# Trying for user number:  538  username:  innocentdemand
# Trying for user number:  539  username:  BooeyBrown
# Trying for user number:  540  username:  vxcosmicowl
# Trying for user number:  541  username:  USS_Turtle
# user not there
# Trying for user number:  542  username:  missjulia928
# Trying for user number:  543  username:  IAreHelen
# Trying for user number:  544  username:  kyriya
# Trying for user number:  545  username:  WhattheNorris
# Trying for user number:  546  username:  rethenut
# Trying for user number:  547  username:  shirleex
# Trying for user number:  548  username:  LiliedHart
# Trying for user number:  549  username:  SkullZ0MBIE
# Trying for user number:  550  username:  ChilledButter13
# Trying for user number:  551  username:  bgcamroux
# Trying for user number:  552  username:  itisarainbow
# Trying for user number:  553  username:  gravijin
# Trying for user number:  554  username:  boardingtheplane
# Trying for user number:  555  username:  nacho_cheezus
# Trying for user number:  556  username:  TracieV42
# Trying for user number:  557  username:  Xeropoint
# Trying for user number:  558  username:  sinyth
# user not there
# Trying for user number:  559  username:  Hollyingrd6
# Trying for user number:  560  username:  hugehair
# Trying for user number:  561  username:  nagese
# Trying for user number:  562  username:  galaxyminstrels
# Trying for user number:  563  username:  cassiopeia1280
# Trying for user number:  564  username:  ohai_megan
# Trying for user number:  565  username:  xsevenx7x
# Trying for user number:  566  username:  SullenArtist
# Trying for user number:  567  username:  blisstake
# Trying for user number:  568  username:  AssassinsHubby07
# Trying for user number:  569  username:  Frykitty
# Trying for user number:  570  username:  summerofsin
# Trying for user number:  571  username:  Molecularx
# Trying for user number:  572  username:  HellsSapper
# Trying for user number:  573  username:  KingOfBongoz
# Trying for user number:  574  username:  Pkumbre
# Trying for user number:  575  username:  SerenadingSiren
# Trying for user number:  576  username:  mrsmorton
# Trying for user number:  577  username:  liimitless
# Trying for user number:  578  username:  vwaexperiance
# Trying for user number:  579  username:  theBR0WNone
# Trying for user number:  580  username:  blessedbe
# Trying for user number:  581  username:  applemint
# Trying for user number:  582  username:  Zosma822
# Trying for user number:  583  username:  RubyRed_DiamondWhite
# Trying for user number:  584  username:  give-em-hell-kid
# Trying for user number:  585  username:  sunnypreposition
# Trying for user number:  586  username:  MsChrissikins
# Trying for user number:  587  username:  jessxdallas
# user not there
# Trying for user number:  588  username:  Odoyl-Rules
# Trying for user number:  589  username:  TheNASAguy
# Trying for user number:  590  username:  girlfromthebasement
# Trying for user number:  591  username:  kruegersar
# Trying for user number:  592  username:  Banjophooee
# user not there
# Trying for user number:  593  username:  AlyKitKat
# Trying for user number:  594  username:  Moonstrucken
# Trying for user number:  595  username:  spacemonkey86
# user not there
# Trying for user number:  596  username:  BabyMonkeyOnPig
# Trying for user number:  597  username:  Temmon
# Trying for user number:  598  username:  Saviour19
# Trying for user number:  599  username:  ImNoland
# Trying for user number:  600  username:  dennycee
# Trying for user number:  601  username:  boardmonkey
# Trying for user number:  602  username:  sslowswimmer
# Trying for user number:  603  username:  AdolfJongUn
# Trying for user number:  604  username:  chipotleplease
# Trying for user number:  605  username:  angelinaxballerina
# Trying for user number:  606  username:  feral_hippie
# Trying for user number:  607  username:  halfkender
# Trying for user number:  608  username:  littlenymphy
# Trying for user number:  609  username:  The_Real_Kuji
# Trying for user number:  610  username:  Rosertot
# Trying for user number:  611  username:  Mandrake158
# Trying for user number:  612  username:  d3photo
# Trying for user number:  613  username:  Ole_frank
# Trying for user number:  614  username:  levislegend
# Trying for user number:  615  username:  Kinky99
# Trying for user number:  616  username:  Stufak
# Trying for user number:  617  username:  TheTrueHighScore
# Trying for user number:  618  username:  foxy704
# Trying for user number:  619  username:  lovensnow
# Trying for user number:  620  username:  uhh_tina_uhh
# Trying for user number:  621  username:  tanny24
# Trying for user number:  622  username:  miratorazh
# Trying for user number:  623  username:  atomic_winter
# Trying for user number:  624  username:  teenaamariee
# Trying for user number:  625  username:  LoverOLife
# Trying for user number:  626  username:  Ryanestrasz
# Trying for user number:  627  username:  OisinS
# Trying for user number:  628  username:  theonewiththetits
# Trying for user number:  629  username:  Resurrected123
# Trying for user number:  630  username:  cimbrag90
# Trying for user number:  631  username:  Makovu
# Trying for user number:  632  username:  Nex_renegade
# Trying for user number:  633  username:  LauraMiggs
# Trying for user number:  634  username:  happywalks
# Trying for user number:  635  username:  LorraineRenee
# Trying for user number:  636  username:  Sconniebuffalo
# Trying for user number:  637  username:  Chunksmommy
# Trying for user number:  638  username:  cxbu
# Trying for user number:  639  username:  Porcelain_princess89
# user not there
# Trying for user number:  640  username:  MichiganCubbie
# Trying for user number:  641  username:  maikeloco
# Trying for user number:  642  username:  tabletopgames
# Trying for user number:  643  username:  greeneyedbaby190
# Trying for user number:  644  username:  AvSheba
# Trying for user number:  645  username:  shypagesniffer
# Trying for user number:  646  username:  juicemagic
# Trying for user number:  647  username:  bananahan11
# Trying for user number:  648  username:  unicorndanceparty
# Trying for user number:  649  username:  1newuser
# Trying for user number:  650  username:  UnicornPlus
# Trying for user number:  651  username:  berrycpie
# Trying for user number:  652  username:  adamp814
# Trying for user number:  653  username:  dordidoo
# Trying for user number:  654  username:  Anairdna
# Trying for user number:  655  username:  zebragrrl
# Trying for user number:  656  username:  BlindLifePilot
# Trying for user number:  657  username:  CherryRiot
# Trying for user number:  658  username:  fesnying
# Trying for user number:  659  username:  Ninja-Pineapples
# Trying for user number:  660  username:  MissBananaBeak
# Trying for user number:  661  username:  brainpatte
# Trying for user number:  662  username:  Menemnesa51
# Trying for user number:  663  username:  rumpie
# Trying for user number:  664  username:  NuclearSky
# Trying for user number:  665  username:  Krw71815
# Trying for user number:  666  username:  DefinetlyNotEoin
# Trying for user number:  667  username:  lovekataralove
# Trying for user number:  668  username:  MegaEpicThunder
# Trying for user number:  669  username:  writeandknow
# Trying for user number:  670  username:  thegirlinpajamas
# Trying for user number:  671  username:  GoJebs
# Trying for user number:  672  username:  PrincessTinyheart
# user not there
# Trying for user number:  673  username:  darkfang013
# Trying for user number:  674  username:  badgirlrelapse
# Trying for user number:  675  username:  spicycanadian
# Trying for user number:  676  username:  LionOfMyth
# Trying for user number:  677  username:  GingerAy
# Trying for user number:  678  username:  Lightsong-The-Bold
# Trying for user number:  679  username:  AnnaDominii
# Trying for user number:  680  username:  divarealness
# Trying for user number:  681  username:  Andrespaco15
# Trying for user number:  682  username:  TroyMcClureJr
# Trying for user number:  683  username:  calvbore
# Trying for user number:  684  username:  noey92r
# Trying for user number:  685  username:  brittany16691
# Trying for user number:  686  username:  cheshire_cat_99
# Trying for user number:  687  username:  featherstones
# Trying for user number:  688  username:  enroutetodonuts
# Trying for user number:  689  username:  ConfusionIntensifies
# Trying for user number:  690  username:  justinebronson
# Trying for user number:  691  username:  serephia
# Trying for user number:  692  username:  PM_ME_LEGAL_PAPERS
# Trying for user number:  693  username:  fondofowls
# Trying for user number:  694  username:  AmIaMuppet
# Trying for user number:  695  username:  valuemenu26
# Trying for user number:  696  username:  PlanetaryUnicorn
# user not there
# Trying for user number:  697  username:  oswin13
# Trying for user number:  698  username:  Ir0nhide
# Trying for user number:  699  username:  NervyFox
# Trying for user number:  700  username:  buffaloguy1991
# Trying for user number:  701  username:  Rectumwarts00
# Trying for user number:  702  username:  SaraSevenfold
# Trying for user number:  703  username:  newsdiva1389
# Trying for user number:  704  username:  Kushalmehta08
# Trying for user number:  705  username:  BoscoBrown
# Trying for user number:  706  username:  bittersweetradio
# Trying for user number:  707  username:  Oodles_of_noodles_
# Trying for user number:  708  username:  China-Palace
# Trying for user number:  709  username:  atrine
# Trying for user number:  710  username:  SymphonyOfInsanity
# Trying for user number:  711  username:  jimjamj
# Trying for user number:  712  username:  KitKatKnitter
# Trying for user number:  713  username:  minal187
# Trying for user number:  714  username:  Bewaretwo
# Trying for user number:  715  username:  ricctp6
# Trying for user number:  716  username:  drakeflaem
# Trying for user number:  717  username:  kimplovely
# Trying for user number:  718  username:  Tommy666567
# Trying for user number:  719  username:  GeekDoesLife
# Trying for user number:  720  username:  Bluetiger811
# Trying for user number:  721  username:  Gui1tyspark
# Trying for user number:  722  username:  Colieoh
# Trying for user number:  723  username:  PimaPotato
# Trying for user number:  724  username:  LostGirl117
# Trying for user number:  725  username:  foreverskylight
# Trying for user number:  726  username:  pitakahlo
# Trying for user number:  727  username:  snowpuffs
# Trying for user number:  728  username:  Joanna0527
# Trying for user number:  729  username:  shyethyme
# Trying for user number:  730  username:  ElegantZebra
# Trying for user number:  731  username:  themeteorites
# Trying for user number:  732  username:  stevebuscemiofficial
# Trying for user number:  733  username:  SilverInTheMine
# Trying for user number:  734  username:  mskrystle
# Trying for user number:  735  username:  Bigluce
# Trying for user number:  736  username:  wdg10
# Trying for user number:  737  username:  evilnoodle84
# Trying for user number:  738  username:  Hiveykins
# Trying for user number:  739  username:  darkviper039
# Trying for user number:  740  username:  baccgirl
# Trying for user number:  741  username:  ft-eoj
# Trying for user number:  742  username:  veneaux
# user not there
# Trying for user number:  743  username:  xfitsally
# Trying for user number:  744  username:  louwolf
# Trying for user number:  745  username:  sleepingshast
# Trying for user number:  746  username:  wearlej
# Trying for user number:  747  username:  MrSquifler
# Trying for user number:  748  username:  kydashian
# Trying for user number:  749  username:  Lettingthatshitgo
# Trying for user number:  750  username:  obviousdscretion
# Trying for user number:  751  username:  ChiChiBoobie
# Trying for user number:  752  username:  adelgirl
# Trying for user number:  753  username:  Scrooge-Jones
# user not there
# Trying for user number:  754  username:  Kororimpa
# Trying for user number:  755  username:  Calamlikeabomb
# Trying for user number:  756  username:  AltruismAndCake
# Trying for user number:  757  username:  WomanInAVan
# Trying for user number:  758  username:  #NAME?
# Trying for user number:  759  username:  vegas_popprincess
# Trying for user number:  760  username:  SatinUnicorn
# Trying for user number:  761  username:  andyq9433
# Trying for user number:  762  username:  TH3KARMACHARGER
# Trying for user number:  763  username:  sytyue
# Trying for user number:  764  username:  Sansanvi
# Trying for user number:  765  username:  olaade
# Trying for user number:  766  username:  ManlyUnic0rn
# Trying for user number:  767  username:  DenyGFX
# user not there
# Trying for user number:  768  username:  Olav_Grey
# Trying for user number:  769  username:  twisted_tk
# Trying for user number:  770  username:  SodapopGatts
# Trying for user number:  771  username:  badgers-n-daffodils
# Trying for user number:  772  username:  Jteph
# Trying for user number:  773  username:  prikulkarni
# Trying for user number:  774  username:  zoebroxx
# Trying for user number:  775  username:  ms_watermelon
# Trying for user number:  776  username:  savage1329
# Trying for user number:  777  username:  JacksBleedingColon
# Trying for user number:  778  username:  AntisocialOatmeal
# Trying for user number:  779  username:  termiteaward
# user not there
# Trying for user number:  780  username:  pumpkin-cat
# Trying for user number:  781  username:  narcicide
# Trying for user number:  782  username:  kukolsghost
# Trying for user number:  783  username:  Elijahs-Wood
# Trying for user number:  784  username:  lazzysunflowerr
# Trying for user number:  785  username:  babyraspberry
# Trying for user number:  786  username:  ElephantRLife
# Trying for user number:  787  username:  Stuffferz
# Trying for user number:  788  username:  jh6196
# Trying for user number:  789  username:  dinosaurweasel
# Trying for user number:  790  username:  girlwhow8d
# Trying for user number:  791  username:  Sonylicious
# Trying for user number:  792  username:  Harrywheeler_
# Trying for user number:  793  username:  inputmethod
# Trying for user number:  794  username:  chartreuselion
# Trying for user number:  795  username:  uncaer9
# Trying for user number:  796  username:  94smitha
# Trying for user number:  797  username:  pumpkin_cheesecake
# Trying for user number:  798  username:  MrTwo-Face
# Trying for user number:  799  username:  TheCivilPsycho
# Trying for user number:  800  username:  BlenlyGetsFit
# Trying for user number:  801  username:  _Anna_Mosity
# Trying for user number:  802  username:  gunnyganatra
# Trying for user number:  803  username:  popbobtai
# Trying for user number:  804  username:  Captain-Nemo
# Trying for user number:  805  username:  poloxamer
# Trying for user number:  806  username:  karossii
# Trying for user number:  807  username:  caniuserthisname
# Trying for user number:  808  username:  lilfruini
# Trying for user number:  809  username:  OdoWanKenobi
# Trying for user number:  810  username:  Catterflies
# Trying for user number:  811  username:  bayouekko
# Trying for user number:  812  username:  Adiboochoo
# Trying for user number:  813  username:  omeganemesis28
# Trying for user number:  814  username:  IAmA_Wolf
# Trying for user number:  815  username:  officiallipgallagher
# user not there
# Trying for user number:  816  username:  used2bgood
# Trying for user number:  817  username:  ow-mylife
# Trying for user number:  818  username:  shlupieus
# Trying for user number:  819  username:  yeahbatman
# Trying for user number:  820  username:  mad_zamboni
# Trying for user number:  821  username:  FelidaeFae
# Trying for user number:  822  username:  donegallite
# Trying for user number:  823  username:  GMD0301
# Trying for user number:  824  username:  pamitata
# Trying for user number:  825  username:  claricia
# Trying for user number:  826  username:  LadyAmpersand
# Trying for user number:  827  username:  tali214
# Trying for user number:  828  username:  Fuzzygumdrop
# Trying for user number:  829  username:  Lainnnn
# Trying for user number:  830  username:  AroseRisen
# Trying for user number:  831  username:  Castiel_the_Angel
# user not there
# Trying for user number:  832  username:  Wombat81
# Trying for user number:  833  username:  VolcanicMeerkat
# Trying for user number:  834  username:  3zero1ne
# Trying for user number:  835  username:  giga-butt
# Trying for user number:  836  username:  dzzi
# Trying for user number:  837  username:  AmericanRuin
# Trying for user number:  838  username:  InfernalCoconut
# Trying for user number:  839  username:  Jonesno11
# Trying for user number:  840  username:  propertyofmycat
# Trying for user number:  841  username:  sturdynerdybirdie
# Trying for user number:  842  username:  darkorical
# Trying for user number:  843  username:  COSMICmist
# Trying for user number:  844  username:  MadameMaxime
# Trying for user number:  845  username:  Pghtoad412
# user not there
# Trying for user number:  846  username:  UNLUCK3
# Trying for user number:  847  username:  kyriedonovan
# Trying for user number:  848  username:  cubeisbetter
# Trying for user number:  849  username:  creepykirk
# Trying for user number:  850  username:  kiizzababy
# Trying for user number:  851  username:  MrFizzles
# Trying for user number:  852  username:  GML2017
# Trying for user number:  853  username:  crrrenee
# Trying for user number:  854  username:  Cruxling
# Trying for user number:  855  username:  thedisenchantedpony
# Trying for user number:  856  username:  watchitexplode
# Trying for user number:  857  username:  Jiddybit
# Trying for user number:  858  username:  icycherry
# Trying for user number:  859  username:  fumonmycace
# Trying for user number:  860  username:  hatefulbitches
# Trying for user number:  861  username:  NerdyBirdyx
# Trying for user number:  862  username:  Agentcocotte
# Trying for user number:  863  username:  AimeeMarieCherie
# Trying for user number:  864  username:  -ksguy-
# Trying for user number:  865  username:  Laprasrides
# Trying for user number:  866  username:  txmoonpie1
# Trying for user number:  867  username:  ABoxOfPencils
# Trying for user number:  868  username:  kjtstl
# Trying for user number:  869  username:  Freakazoid444
# Trying for user number:  870  username:  Supercatgirl
# Trying for user number:  871  username:  lashyy
# Trying for user number:  872  username:  BlakeHRS
# Trying for user number:  873  username:  Destins_Destiny
# Trying for user number:  874  username:  Ershley
# Trying for user number:  875  username:  medula-onlongata
# user not there
# Trying for user number:  876  username:  hotcheetos0489
# Trying for user number:  877  username:  supermariobras
# Trying for user number:  878  username:  Marine915
# Trying for user number:  879  username:  WorkThreadGazer
# Trying for user number:  880  username:  ironysparkles
# Trying for user number:  881  username:  Nia04
# Trying for user number:  882  username:  wolfykinns
# Trying for user number:  883  username:  cinderflight
# Trying for user number:  884  username:  misuzu_solo
# Trying for user number:  885  username:  Miss-E-xo
# Trying for user number:  886  username:  DovakiinBF3FTW
# user not there
# Trying for user number:  887  username:  tootshores
# Trying for user number:  888  username:  SimplyAvocado
# Trying for user number:  889  username:  fukinell
# Trying for user number:  890  username:  Amecha
# Trying for user number:  891  username:  fernxqueen
# Trying for user number:  892  username:  Mafiya_chlenom_K
# Trying for user number:  893  username:  Ellytry2besweet4me
# Trying for user number:  894  username:  Ivyson1
# Trying for user number:  895  username:  Jmcarter80
# Trying for user number:  896  username:  GMan85
# Trying for user number:  897  username:  BeachJas
# Trying for user number:  898  username:  DOA
# Trying for user number:  899  username:  Cat-UnicornHybrid
# user not there
# Trying for user number:  900  username:  canwejustno
# Trying for user number:  901  username:  _ijustliketoread_
# Trying for user number:  902  username:  NitroMuffin
# Trying for user number:  903  username:  GreatGooglyMoogly55
# Trying for user number:  904  username:  Nextstarover
# ...
# Trying for user number:  1047  username:  rabbita
# Trying for user number:  1048  username:  YoshiSparkle
# Trying for user number:  1049  username:  UnAuthorize
# Trying for user number:  1050  username:  birdladymelia
# Trying for user number:  1051  username:  isaiahexe
# Trying for user number:  1052  username:  Baylorbelle
# Trying for user number:  1053  username:  camelemoji
# Trying for user number:  1054  username:  samsta555
# Trying for user number:  1055  username:  nytetears
# Trying for user number:  1056  username:  upsidedownintj
# Trying for user number:  1057  username:  Blueberry49
# Trying for user number:  1058  username:  ndurgun
# Trying for user number:  1059  username:  JeruDD
# Trying for user number:  1060  username:  Everlastingwishes
# Trying for user number:  1061  username:  Mattybmate
# Trying for user number:  1062  username:  jessdb19
# Trying for user number:  1063  username:  droppedinthedeepend
# Trying for user number:  1064  username:  ReticulateLemur
# Trying for user number:  1065  username:  kissmyasthma99-99
# Trying for user number:  1066  username:  asutch12
# Trying for user number:  1067  username:  oldmanfiend
# Trying for user number:  1068  username:  rilekit
# Trying for user number:  1069  username:  Cyanidesuicideml
# Trying for user number:  1070  username:  JackCloudie
# Trying for user number:  1071  username:  revolution486
# Trying for user number:  1072  username:  BurnAccount1974
# Trying for user number:  1073  username:  wecouldbeimmortals
# Trying for user number:  1074  username:  KatsMeyow
# Trying for user number:  1075  username:  GRswim10
# Trying for user number:  1076  username:  carlin2345
# Trying for user number:  1077  username:  tierrexx
# Trying for user number:  1078  username:  Danielledaydreamer1
# Trying for user number:  1079  username:  drproximo
# Trying for user number:  1080  username:  coffeebugtravels
# Trying for user number:  1081  username:  swanniebear
# Trying for user number:  1082  username:  JRPGNATION
# Trying for user number:  1083  username:  Kite_Moonwall
# Trying for user number:  1084  username:  Savascha
# Trying for user number:  1085  username:  verissey
# Trying for user number:  1086  username:  The_Quantum_Moose
# Trying for user number:  1087  username:  stefani187
# Trying for user number:  1088  username:  abby080798
# Trying for user number:  1089  username:  247naptime
# Trying for user number:  1090  username:  transemacabre
# Trying for user number:  1091  username:  Candicehxo
# Trying for user number:  1092  username:  MissPerry
# Trying for user number:  1093  username:  ninehundredways
# Trying for user number:  1094  username:  anaesthetic
# Trying for user number:  1095  username:  Kandydish
# Trying for user number:  1096  username:  Chain-smokers
# user not there
# Trying for user number:  1097  username:  DaRoyalJester
# Trying for user number:  1098  username:  ReapeRx124
# Trying for user number:  1099  username:  Mrs_partyrocq
# Trying for user number:  1100  username:  HuggingTheJellyfish
# Trying for user number:  1101  username:  Whoop314
# Trying for user number:  1102  username:  Kerackers
# Trying for user number:  1103  username:  sasaelle
# Trying for user number:  1104  username:  ThePrince_OfWhales
# Trying for user number:  1105  username:  Fiddlestix22
# Trying for user number:  1106  username:  michiruwater
# Trying for user number:  1107  username:  salmananees
# Trying for user number:  1108  username:  WeedWidaMacka
# Trying for user number:  1109  username:  laulluke
# user not there
# Trying for user number:  1110  username:  BoiseState7
# Trying for user number:  1111  username:  Apocalypsze
# Trying for user number:  1112  username:  taylorbobalor420
# Trying for user number:  1113  username:  thriftymargo
# Trying for user number:  1114  username:  SenseiCooper
# Trying for user number:  1115  username:  Phantom-viper
# Trying for user number:  1116  username:  Dispand
# Trying for user number:  1117  username:  Bazinga313
# Trying for user number:  1118  username:  WhatIsAccent
# Trying for user number:  1119  username:  AuberonFinn
# Trying for user number:  1120  username:  xolrumi
# Trying for user number:  1121  username:  puppiespuppyspuppies
# Trying for user number:  1122  username:  REW0702
# Trying for user number:  1123  username:  ex-spiravit
# Trying for user number:  1124  username:  kaetia
# Trying for user number:  1125  username:  giraffeluv
# Trying for user number:  1126  username:  PappaOrangutan
# Trying for user number:  1127  username:  _kristina
# Trying for user number:  1128  username:  Paradox_Artemis
# Trying for user number:  1129  username:  lazydaisystitcher
# Trying for user number:  1130  username:  shrinktastic
# Trying for user number:  1131  username:  Kisitiene
# Trying for user number:  1132  username:  kcasp
# Trying for user number:  1133  username:  AwkwardRainbow
# Trying for user number:  1134  username:  totallypandacoffee
# Trying for user number:  1135  username:  QuickWittedSlowpoke
# Trying for user number:  1136  username:  Crockpotbob
# Trying for user number:  1137  username:  tardiswolf
# Trying for user number:  1138  username:  BloodyStigmata
# Trying for user number:  1140  username:  themedicduck
# Trying for user number:  1141  username:  Land-Stander
# Trying for user number:  1142  username:  Letonoda
# Trying for user number:  1143  username:  XvOnEvX
# Trying for user number:  1144  username:  stellaby
# Trying for user number:  1145  username:  Biiou
# Trying for user number:  1146  username:  lean_machim
# Trying for user number:  1147  username:  nancydrewskillz
# Trying for user number:  1148  username:  Sanomaly_
# Trying for user number:  1149  username:  thealmightykatt
# Trying for user number:  1150  username:  JamieAMSullivan
# Trying for user number:  1151  username:  rave1432
# Trying for user number:  1152  username:  fillyourselfwithgold
# Trying for user number:  1153  username:  totesvaguish
# Trying for user number:  1154  username:  Rex0101
# user not there
# Trying for user number:  1155  username:  Thisusernameisdope
# Trying for user number:  1157  username:  red_death_at_614
# Trying for user number:  1158  username:  EvanatorT800
# Trying for user number:  1159  username:  RiseUP21
# Trying for user number:  1160  username:  afloodbehind
# Trying for user number:  1161  username:  mr-photo
# Trying for user number:  1162  username:  Privilegedwhitebitch
# Trying for user number:  1163  username:  Mike-3D-Animator
# Trying for user number:  1164  username:  cezzatron
# Trying for user number:  1165  username:  jasonamonroe
# Trying for user number:  1166  username:  Sebxlo
# Trying for user number:  1167  username:  mrfilbert
# Trying for user number:  1168  username:  rumbleberrypie
# Trying for user number:  1169  username:  InThisHouse19
# Trying for user number:  1170  username:  bec-t99
# Trying for user number:  1171  username:  d1nos0r
# Trying for user number:  1172  username:  cherchezlafemmed
# Trying for user number:  1173  username:  lolly_lag
# Trying for user number:  1174  username:  Unfortunate_Dildo
# Trying for user number:  1175  username:  unedant
# Trying for user number:  1176  username:  diligence_is_key
# Trying for user number:  1177  username:  arizzles
# Trying for user number:  1178  username:  SkySeaSkySeaaaa
# Trying for user number:  1179  username:  HieixKillua
# Trying for user number:  1180  username:  pm_me_your_SPECIALs
# Trying for user number:  1181  username:  kuailong
# Trying for user number:  1182  username:  PlatinumAmphibian
# Trying for user number:  1183  username:  morgan_mayhem
# Trying for user number:  1184  username:  electrictitfluff
# Trying for user number:  1185  username:  insouciantelle
# Trying for user number:  1186  username:  lovelyxosunshine
# user not there
# Trying for user number:  1187  username:  shemms
# Trying for user number:  1188  username:  AA0X
# Trying for user number:  1189  username:  kingfishersam
# Trying for user number:  1190  username:  louisxfuton
# Trying for user number:  1191  username:  BendersMom
# Trying for user number:  1192  username:  cmantra
# Trying for user number:  1193  username:  one_hotmess
# Trying for user number:  1194  username:  scrapcats
# Trying for user number:  1195  username:  Fuxkily
# Trying for user number:  1196  username:  nfh__
# user not there
# Trying for user number:  1197  username:  ThePorcupineWizard
# Trying for user number:  1198  username:  Milkarium
# Trying for user number:  1199  username:  eekabee
# Trying for user number:  1200  username:  illusivesamurai
# Trying for user number:  1201  username:  kindoldtree
# Trying for user number:  1202  username:  unbirthdayhatter
# Trying for user number:  1203  username:  CarterLawler
# Trying for user number:  1204  username:  yeahbutitspretty
# Trying for user number:  1205  username:  chrisrb93
# Trying for user number:  1206  username:  scribblebug
# Trying for user number:  1207  username:  boatiemcboat
# Trying for user number:  1208  username:  redd1tr1dingh00d
# Trying for user number:  1209  username:  Andimichelle13
# Trying for user number:  1210  username:  embersue
# Trying for user number:  1211  username:  tealhena
# Trying for user number:  1212  username:  summersperi
# Trying for user number:  1213  username:  datotherdude
# Trying for user number:  1214  username:  tikiyadenola
# Trying for user number:  1215  username:  stikkysaladtongs
# Trying for user number:  1216  username:  M-JdotJ
# Trying for user number:  1217  username:  yunolikemem8
# Trying for user number:  1218  username:  EFCFrost
# Trying for user number:  1219  username:  xxlemonchan
# Trying for user number:  1220  username:  FiveFourThreeNoseOne
# Trying for user number:  1221  username:  Taboada12
# Trying for user number:  1222  username:  suomynonAx
# Trying for user number:  1223  username:  ikeyzone
# Trying for user number:  1224  username:  Shortelle
# Trying for user number:  1225  username:  elixan
# Trying for user number:  1226  username:  CamoAndCrowns
# Trying for user number:  1227  username:  jellirollo
# Trying for user number:  1228  username:  thatgirlisaproblem
# Trying for user number:  1229  username:  HasALittleFaith
# Trying for user number:  1230  username:  Vienaragis90
# Trying for user number:  1231  username:  GenghisTron333
# Trying for user number:  1232  username:  mycello
# Trying for user number:  1233  username:  qmracer01
# Trying for user number:  1234  username:  Psychovore
# Trying for user number:  1235  username:  Squishee-Face
# Trying for user number:  1236  username:  LucyGoosey5
# Trying for user number:  1237  username:  Clquigs
# Trying for user number:  1238  username:  Lord0fTheHarem
# user not there
# Trying for user number:  1239  username:  skekVex
# Trying for user number:  1240  username:  MadgePadge
# Trying for user number:  1241  username:  Travis100
# Trying for user number:  1242  username:  ABNDT
# Trying for user number:  1243  username:  hyrulerofcanada
# Trying for user number:  1244  username:  iloverickmoranis
# Trying for user number:  1245  username:  daijoubudayo
# Trying for user number:  1246  username:  epion-viragos
# Trying for user number:  1247  username:  melvinismad
# Trying for user number:  1248  username:  minisixx
# Trying for user number:  1249  username:  Tramiiepoo
# Trying for user number:  1250  username:  idene
# Trying for user number:  1251  username:  linzal87
# Trying for user number:  1252  username:  yaanchan
# Trying for user number:  1253  username:  ntmyrealacct
# Trying for user number:  1254  username:  devilpuppy
# Trying for user number:  1255  username:  HearingSword
# Trying for user number:  1256  username:  Wackydude1234
# Trying for user number:  1257  username:  Emicarn
# Trying for user number:  1258  username:  larastro
# Trying for user number:  1259  username:  Chihuahua_enthusiast
# Trying for user number:  1260  username:  IRunLikeGoku
# user not there
# Trying for user number:  1261  username:  me_and_jd
# Trying for user number:  1262  username:  _welcomehome_
# Trying for user number:  1263  username:  goldengraaam
# Trying for user number:  1264  username:  definitelydes1
# Trying for user number:  1265  username:  Omar_93
# Trying for user number:  1266  username:  nedstrom
# Trying for user number:  1267  username:  greyboy87
# Trying for user number:  1268  username:  Bug_Hugger
# Trying for user number:  1269  username:  emilelele
# Trying for user number:  1270  username:  weirdpancake
# Trying for user number:  1271  username:  Myspacecutie69
# Trying for user number:  1272  username:  corpsey_
# Trying for user number:  1273  username:  AT1990
# Trying for user number:  1274  username:  Accurchet
# Trying for user number:  1275  username:  Bisut
# Trying for user number:  1276  username:  AmiMizuno27
# Trying for user number:  1277  username:  Dia-the-Novakid
# Trying for user number:  1278  username:  DarkInanna
# Trying for user number:  1279  username:  Anam_Cara
# Trying for user number:  1280  username:  kellypryde
# Trying for user number:  1281  username:  CanadianGamer001
# Trying for user number:  1282  username:  rabidproblemdog
# Trying for user number:  1283  username:  Buffy2017
# Trying for user number:  1284  username:  JayhawkColby
# Trying for user number:  1285  username:  Seobooty
# Trying for user number:  1286  username:  ladysilarial
# Trying for user number:  1287  username:  1_XP_Wasted
# Trying for user number:  1288  username:  breaksyourheart
# Trying for user number:  1289  username:  cuppycake10-4
# Trying for user number:  1290  username:  Charleafy
# Trying for user number:  1291  username:  mulan3237
# Trying for user number:  1292  username:  brassmonkeyslc
# Trying for user number:  1293  username:  kelsygram
# Trying for user number:  1294  username:  maloner1
# Trying for user number:  1295  username:  bizarregospel
# Trying for user number:  1296  username:  TheCaptainIsHere
# Trying for user number:  1297  username:  incumbent
# Trying for user number:  1298  username:  danimarie72
# Trying for user number:  1299  username:  Miss_LJ
# Trying for user number:  1300  username:  ZombiesInMyGarden
# Trying for user number:  1301  username:  RagdollMankind
# Trying for user number:  1302  username:  renlotus
# Trying for user number:  1303  username:  SierraScott910
# Trying for user number:  1304  username:  irlgarbodor
# Trying for user number:  1305  username:  cristenen
# Trying for user number:  1306  username:  BoldnBrashes
# Trying for user number:  1307  username:  ASilverSpartan
# Trying for user number:  1308  username:  Tiny-Senpai
# Trying for user number:  1309  username:  Jephimykes
# Trying for user number:  1310  username:  KaeAlexandria
# Trying for user number:  1311  username:  Anastasia_23
# user not there
# Trying for user number:  1312  username:  thepearloather
# Trying for user number:  1313  username:  AtrocityXhibition
# Trying for user number:  1314  username:  k3rizz3k
# Trying for user number:  1315  username:  hemlockdalise
# Trying for user number:  1316  username:  samanthapwnsall
# Trying for user number:  1317  username:  TandT89
# Trying for user number:  1318  username:  Jumbo_Cactaur
# Trying for user number:  1319  username:  wonderb0lt
# Trying for user number:  1320  username:  RaptorGoRawr
# Trying for user number:  1321  username:  PaulFTW87
# Trying for user number:  1322  username:  MicCheckTapTapTap
# Trying for user number:  1323  username:  laurenuniverse
# Trying for user number:  1324  username:  BroghanTaylor
# Trying for user number:  1325  username:  myke113
# Trying for user number:  1326  username:  koila_
# Trying for user number:  1327  username:  Zockman175
# Trying for user number:  1328  username:  BigBadJimmie
# Trying for user number:  1329  username:  TheIndiglo
# Trying for user number:  1330  username:  Jaime918
# Trying for user number:  1331  username:  Peaceandloveonearth
# Trying for user number:  1332  username:  Jedi-Guy
# Trying for user number:  1333  username:  k1ngm3
# Trying for user number:  1334  username:  Babycrazy96
# Trying for user number:  1335  username:  Misanthrokarmic
# Trying for user number:  1336  username:  annabanda
# Trying for user number:  1337  username:  agreatperhapswaits
# Trying for user number:  1338  username:  majestic_cats
# Trying for user number:  1339  username:  bkk291
# Trying for user number:  1340  username:  IGiveDumbCompliments

# %% [markdown]
# If you are running the script, run the cell below to avoid waiting a bunch for the code above.

# %%
#If you are running this script, please just use this as the Dataframe
df=pd.DataFrame.from_csv('redditproducts.csv')
# If you are running the script then run this cell. My functions 
import ast
newlist = []
for i in range(len(df)):
    try:
        print(i)
        newlist.append(ast.literal_eval(df['Subs'][i]))
        print(type(newlist[i]))
    except:
        print(i,'Null Subs, user does not exist')
        newlist.append('Null')
df['Subs']=newlist
# Out:
# 0
# <class 'set'>
# 1
# <class 'set'>
# 2
# <class 'set'>
# 3
# <class 'set'>
# 4
# <class 'set'>
# 5
# <class 'set'>
# 6
# <class 'set'>
# 7
# <class 'set'>
# 8
# <class 'set'>
# 9
# <class 'set'>
# 10
# <class 'set'>
# 11
# <class 'set'>
# 12
# <class 'set'>
# 13
# <class 'set'>
# 14
# <class 'set'>
# 15
# <class 'set'>
# 16
# <class 'set'>
# 17
# <class 'set'>
# 18
# <class 'set'>
# 19
# <class 'set'>
# 20
# <class 'set'>
# 21
# <class 'set'>
# 22
# <class 'set'>
# 23
# <class 'set'>
# 1263
# <class 'set'>
# 1264
# <class 'set'>
# 1265
# <class 'set'>
# 1266
# <class 'set'>
# 1267
# <class 'set'>
# 1268
# <class 'set'>
# 1269
# <class 'set'>
# 1270
# <class 'set'>
# 1271
# <class 'set'>
# 1272
# <class 'set'>
# 1273
# <class 'set'>
# 1274
# <class 'set'>
# 1275
# <class 'set'>
# 1276
# <class 'set'>
# 1277
# <class 'set'>
# 1278
# <class 'set'>
# 1279
# <class 'set'>
# 1280
# <class 'set'>
# 1281
# <class 'set'>
# 1282
# <class 'set'>
# 1283
# <class 'set'>
# 1284
# <class 'set'>
# 1285
# <class 'set'>
# 1286
# <class 'set'>
# 1287
# <class 'set'>
# 1288
# <class 'set'>
# 1289
# <class 'set'>
# 1290
# <class 'set'>
# 1291
# <class 'set'>
# 1292
# <class 'set'>
# 1293
# <class 'set'>
# 1294
# <class 'set'>
# 1295
# <class 'set'>
# 1296
# <class 'set'>
# 1297
# <class 'set'>
# 1298
# <class 'set'>
# 1299
# <class 'set'>
# 1300
# <class 'set'>
# 1301
# <class 'set'>
# 1302
# <class 'set'>
# 1303
# <class 'set'>
# 1304
# <class 'set'>
# 1305
# <class 'set'>
# 1306
# <class 'set'>
# 1307
# <class 'set'>
# 1308
# <class 'set'>
# 1309
# <class 'set'>
# 1310
# <class 'set'>
# 1311
# 1311 Null Subs, user does not exist
# 1312
# <class 'set'>
# 1313
# <class 'set'>
# 1314
# <class 'set'>
# 1315
# <class 'set'>
# 1316
# <class 'set'>
# 1317
# <class 'set'>
# 1318
# <class 'set'>
# 1319
# <class 'set'>
# 1320
# <class 'set'>
# 1321
# <class 'set'>
# 1322
# <class 'set'>
# 1323
# <class 'set'>
# 1324
# <class 'set'>
# 1325
# <class 'set'>
# 1326
# <class 'set'>
# 1327
# <class 'set'>
# 1328
# <class 'set'>
# 1329
# <class 'set'>
# 1330
# <class 'set'>
# 1331
# <class 'set'>
# 1332
# <class 'set'>
# 1333
# <class 'set'>
# 1334
# <class 'set'>
# 1335
# <class 'set'>

# %% [markdown]
# We will use jaccard similarity to find similar subreddits. Jaccard similarity is computed by taking the intersections and dividing by the union of two sets. The function will take 4 arguments, the username, dbsubs, usersubs and the url. We wll return a list that has the username of the potential match, the similarity score and the recommendation link. We also have to check if the usersubs field is a set, since if we return a 'Null' string if the user doesn't exist when populating the list of subs.

# %%
def jaccardsimilarity(username,dbsubs,usersubs,link):
    temp = []
    temp.append(username)
    if type(dbsubs)==set:
        intersection = dbsubs.intersection(usersubs)
        temp.append(intersection)
        score = (len(intersection)/len(dbsubs.union(usersubs)))
        temp.append(score)
        temp.append(link)
        return temp
    else: 
        score = 0
        temp.append('Not Active User')
        temp.append(score)
        return temp

# %% [markdown]
# Now we put it all together. We check to see if its a valid usersanme. Then we iterate through our dataframe. We create a temporary list and run it through our jaccard similarity function. We then sort it by the jaccard similarity cost (in descending order) and prune out all but the top 5 results. Then we just loop through the list and print our results.

# %%
def main(username):
    cesc = []
    try:
        usersubs = getsubs(username)
    except:
        print("Not a valid username.")
        return 
    for i in range(len(df)-1):
    
        try:
            cesc.append(jaccardsimilarity(df['User'][i],df['Subs'][i],usersubs,df['New Url'][i]))
        except:
            continue
    # Sort the list by the 3rd item, the Jaccard similarity score
    sortedlist = sorted(cesc,key=itemgetter(2),reverse=True)
    # Return the top 5 results
    sortedlist = sortedlist[:5]
    print("Your reddit twins are:")
    
    for i in sortedlist:
        print('http://www.reddit.com/u/'+str(i[0]))
        print('Similarity Score:',i[2])
        print('The Subreddits you share are: ',i[1])
        print('And here is some stuff they like. Check it out you may like it as well! ' ,i[3] )

# %%
# Just call main with your username as a string to run the recommender
username = 'abhi91'
main(username)
# Out:
# Your reddit twins are:
# http://www.reddit.com/u/CelticMara
# Similarity Score: 0.0759493670886076
# The Subreddits you share are:  {'videos', 'The_Donald', 'politics', 'asoiaf', 'movies', 'gameofthrones'}
# And here is some stuff they like. Check it out you may like it as well!  https://www.amazon.com/gp/registry/wishlist/3F7V5UDKFLX6G/ref=top&tag=reddittwin-20
# http://www.reddit.com/u/hugehair
# Similarity Score: 0.07317073170731707
# The Subreddits you share are:  {'Overwatch', 'rickandmorty', 'videos', 'The_Donald', 'politics', 'Jokes'}
# And here is some stuff they like. Check it out you may like it as well!  https://www.amazon.com/gp/registry/wishlist/2FFJNK4E8C1GX/ref=top&tag=reddittwin-20
# http://www.reddit.com/u/skekVex
# Similarity Score: 0.07142857142857142
# The Subreddits you share are:  {'me_irl', 'Overwatch', 'hearthstone', 'videos', 'reactiongifs', 'movies'}
# And here is some stuff they like. Check it out you may like it as well!  http://a.co/9ksbaaR
# http://www.reddit.com/u/EmergencyPizza
# Similarity Score: 0.07079646017699115
# The Subreddits you share are:  {'me_irl', 'Overwatch', 'Games', 'videos', 'politics', 'Jokes', 'movies', 'whowouldwin'}
# And here is some stuff they like. Check it out you may like it as well!  https://www.amazon.com/gp/registry/wishlist/1COQNWVXNQ6VT/ref=top&tag=reddittwin-20
# http://www.reddit.com/u/laulluke
# Similarity Score: 0.06862745098039216
# The Subreddits you share are:  {'hearthstone', 'rickandmorty', 'iamverysmart', 'politics', 'reactiongifs', 'movies', 'gameofthrones'}
# And here is some stuff they like. Check it out you may like it as well!  http://amzn.eu/4fffJmf

# %%
df.to_csv('redditproducts.csv')

# %% [markdown]
# # Limitations and Next Steps
#
# I tested my tool with 10 of my friends and got some feedback. It was clear that the results were not in the best format possible. I am returning wishlists rather than individual products. Some of these wishlists have mundane items like snacks and giftcards which is a poor recommendation for users. However, there are some interesting products like board games and books that my friends found intriguing. Of course, I want to test the tool on more than 10 people. I plan on publishing this tool online and trying to use reddit to generate traffic to it. I want to encourage people to tip their reddit match or buy them something from their wishlists, as this would incentivize them to submit their own Amazon wishlists and make my seed dataset richer. I hope that as more and more people use the tool and sign up, the product starts recommending cooler and cooler things for people to find. This cycle of generosity and altruism married with finding novel products, in my opinion, would be a great tool for redditors and showcase that an efficient peer to peer recommendation engine can be built by sharing interests with each other rather than with a company.
